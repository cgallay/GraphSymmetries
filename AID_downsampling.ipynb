# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from PIL import  Image
import glob

# %%
dataset = ImageFolder('dataset/AID/') #transform=transforms.Compose([transforms.Resize((100,100))]))

# %%
resize = transforms.Resize((200, 200))
for img_path in glob.glob('dataset/AID/**/*.jpg'):
    # print(img_path)
    img = Image.open(img_path)
    img = resize(img)
    img.save(img_path)
resize(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2CF3F70EF0>

# %%
resize2 = transforms.Resize((600, 600))

# %%
resize2(resize(dataset[2337][0]))
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F2D498A2BA8>
